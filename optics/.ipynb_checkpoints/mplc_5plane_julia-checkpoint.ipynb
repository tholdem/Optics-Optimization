# %%
## the file to simulate light conversion by multiplanes
using LinearAlgebra,Polynomials,Printf,Random,ForwardDiff,Zygote,PyPlot,PyCall,OffsetArrays,FFTW

# %%
np=pyimport("numpy")
# Out:
# PyObject <module 'numpy' from 'C:\\Users\\bryan\\.juliapro\\JuliaPro_v1.4.2-1\\Conda_env\\lib\\site-packages\\numpy\\__init__.py'>

# %% [markdown]
# ## helper functions

# %%
function opt_fft2(X)
    #center shifted fourier transform
    X_frq = fftshift(fft(ifftshift(X)))
    return X_frq
end

function opt_ifft2(X_frq)
    #center shifted inverse fourier transform
    X = fftshift(ifft(ifftshift(X_frq)))
    return X
end

function make_prop_kernel( sz, z; dl=2,lmbd=0.5, noShift = true)
    nx = sz[1]
    ny = sz[2]
    k=2*pi/lmbd # wavenumber
    dkx=2*pi/((nx-1)*dl)
    dky=2*pi/((ny-1)*dl)
    kx=(LinRange(0,nx-1,nx).-nx/2)*dkx
    ky=(LinRange(0,ny-1,ny).-ny/2)*dky

    inflate(f, kx, ky) = [f(x,y) for x in kx, y in ky]
    f(kx,ky)=exp(1im*sqrt(k^2-kx^2-ky^2)*z)

    prop_kernel=inflate(f,kx,ky)

    if noShift == true
        prop_kernel = ifftshift(prop_kernel)
    end
    return prop_kernel
end

function light_prop2(e_in, prop_kernel;noShift = true)
    if ndims(e_in) == 3
        prop_kernel = reshape(prop_kernel,(1,size(prop_kernel)...))
    end
    if noShift == true
        ek_in  = fft(ifftshift(e_in))
        ek_out = ek_in.*prop_kernel
        e_out  = fftshift(ifft(ek_out))
    else
        ek_in  = opt_fft2(e_in)
        ek_out = ek_in.*prop_kernel
        e_out  = opt_ifft2(ek_out)
    end
    return e_out
end

function phase_mod(e_in, theta; samp_ratio=1)
    #=
    e_in is the input field
    theta is the phase mask
    samp_ratio is the pixel size ratio between the phase mask and the e field 
    =#
    if ndims(e_in) == 2
        if samp_ratio == 1
            e_out = e_in.*exp.(1im*theta)
        else
            e_out = e_in.*kron(exp.(1im*theta),ones((samp_ratio,samp_ratio)))
        end
    elseif ndims(e_in) == 3
        if samp_ratio == 1
            M = exp.(1im*theta)
            e_out = e_in.*reshape(M,(1,size(M)...))
        else
            M = kron(exp.(1im*theta),ones((samp_ratio,samp_ratio)))
            e_out = e_in.*reshape(M,(1,size(M)...))
        end
    end
    return e_out
end
# Out:
# phase_mod (generic function with 1 method)

# %%
function light_prop(e_in, z; dl=2, lmbd=0.5)
    #=
    light propagation at distance z
    e_in: input field
    z: propagation distance
    dl: pixel size in um
    lmbd: wavelength in um
    =#
    if ndims(e_in) == 2
        nx, ny = size(e_in)
    elseif ndims(e_in) == 3
        nf, nx, ny = size(e_in)
    end
            
    k=2*pi/lmbd # wavenumber
    dkx=2*pi/((nx-1)*dl)
    dky=2*pi/((ny-1)*dl)
    kx=(LinRange(0,nx-1,nx).-nx/2)*dkx
    ky=(LinRange(0,ny-1,ny).-ny/2)*dky
    
    inflate(f, kx, ky) = [f(x,y) for x in kx, y in ky]
    f(kx,ky)=exp(1im*sqrt(k^2-kx^2-ky^2)*z)
    
    prop_kernel=inflate(f,kx,ky)
    #prop_kernel=np.exp(1j*(k-(kx_c**2+ky_c**2)/2/k)*z)
    if ndims(e_in) == 2
        ek_in = opt_fft2(e_in)
        ek_out = ek_in.*prop_kernel
        e_out = opt_ifft2(ek_out)
    elseif ndims(e_in) == 3
        e_out = zeros(ComplexF64,size(e_in))
        for ii = 1:nf
            ek_in = opt_fft2(e_in[ii,:,:])
            ek_out = ek_in.*prop_kernel
            e_out[ii,:,:] = opt_ifft2(ek_out)
        end
    end
    return e_out
end

# %%
s_input
# Out:
# 10×2 Array{Any,2}:
#   -63.6396   -63.6396
#  -127.279   -127.279
#     0.0     -127.279
#  -190.919   -190.919
#   -63.6396  -190.919
#    63.6396  -190.919
#  -254.558   -254.558
#  -127.279   -254.558
#     0.0     -254.558
#   127.279   -254.558

# %% [markdown]
# ## Design of a 5-plane Optimization

# %%
# wavelength
lmbd = 0.5 # in um
# coordinates
nx = 256
ny = 256
# pixel size
dl = 5 # unit um
#number of plates
npl = 5

x=(LinRange(0,nx-1,nx).-nx/2)*dl
y=(LinRange(0,ny-1,ny).-ny/2)*dl

s_input = Matrix(undef,sum(1:npl-1),2)
p = 90 # pitch
k=0
for  ii =1:npl-1
    ys = -ii*p*sqrt(2)/2
    for jj =0:ii-1
        k+=1
        xs = ys + jj*p*sqrt(2)
        s_input[k,:]=[xs,ys]
    end
end

nmod = size(s_input,1)
e_in = zeros(nmod, ny, nx)
w_in = 30 # beam width
inflate(f, x, y, i) = [f(xx,yy,i) for xx in x, yy in y]
f(x,y,i)=exp(-((x-s_input[i,1])^2+(y-s_input[i,2])^2)/w_in^2)
for ii = 1:nmod
    e = inflate(f,x,y,ii)
    I = sum(abs2,e)
    e_in[ii,:,:] = e'/sqrt(I)
end

fig, ax = plt.subplots()
image=ax.imshow(dropdims(sum(e_in, dims=1),dims=1))
cbar=plt.colorbar(image)  

# output
e_out = zeros(nmod, ny, nx)
w_out = 200
inflate(f, x, y) = [f(xx,yy) for xx in x, yy in y]
f(x,y)=exp(-(x^2+y^2)/w_out^2)
M = inflate(f,x,y)

for  ii = 1:npl-1
    for jj = 1:ii
        c = zeros(jj,ii-jj+1)
        c[jj,ii-jj+1]=1
        e = np.polynomial.hermite.hermgrid2d(sqrt(2)*x/w_out, sqrt(2)*y/w_out, c).*M
        I = sum(abs2,e)
        kk = fld(ii*(ii-1),2)+jj# list index
        e_out[kk,:,:] = e/sqrt(I)
    end
end

fig, ax = subplots()
image=ax.imshow(e_out[1,:,:])
cbar=colorbar(image)
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x00000000018DF788>

# %%
## 5 plates in between
npl = 5
d = [2e4,2.5e4,2.5e4,2.5e4,2.5e4,2e4]
theta = zeros(npl,nx,ny)
e_fwd = zeros(ComplexF64,npl+2,nmod,nx,ny) 
e_bwd = zeros(ComplexF64,npl+2,nmod,nx,ny) 
e_fwd[1,:,:,:] = e_in
e_bwd[end,:,:,:] = e_out

# Stephen
noShift = true
kernelsForward   = zeros(ComplexF64,(npl+1,nx,ny))
kernelsBackward  = zeros(ComplexF64,(npl+1,nx,ny))
for jj = 1:npl+1
  kernelsForward[jj,:,:] = make_prop_kernel( (nx,ny), d[jj],dl=dl,lmbd=lmbd, noShift = noShift)
  kernelsBackward[jj,:,:] = make_prop_kernel( (nx,ny), -d[jj],dl=dl,lmbd=lmbd, noShift = noShift)
end
forwardPropagate(e_in, jj)  = light_prop2(e_in, kernelsForward[jj,:,:], noShift = noShift)
backwardPropagate(e_in, jj) = light_prop2(e_in, kernelsBackward[jj,:,:], noShift = noShift)

e_fwd_m = e_in
# initial backpropagate
e_bwd_m = e_out # modulated field

ind = vcat([npl+1],collect(1:npl-1))

for jj = 1:npl
    #e_bwd[-jj-2,:,:,:] = light_prop(e_bwd_m, -d[-jj-1], dl, lmbd)#backpropagates        
    e_bwd[end-jj,:,:,:] = backwardPropagate( e_bwd_m, ind[jj] )
    e_bwd_m = phase_mod(e_bwd[end-jj,:,:,:], -theta[end-jj+1,:,:], samp_ratio=1)
end

nitr = 100 # number of iteration
# nitr = 2  # Stephen
#nitr = 300  # Stephen

function mainLoop()
    for ii = 1:nitr
        # forward update   
        e_fwd_m = e_in # initial modulated field
        # Compute forward propagation model
        for jj = 1:npl  # loop over plate
            # e_fwd[jj+1,:,:,:] = light_prop(e_fwd_m, d[jj], dl, lmbd)
            e_fwd[jj+1,:,:,:] = forwardPropagate(e_fwd_m, jj)
            e_sum = sum(e_fwd[jj+1,:,:,:].*conj.(e_bwd[jj+1,:,:,:]),dims=1)
            theta[jj,:,:] = -angle.(e_sum) # updates
            e_fwd_m = phase_mod(e_fwd[jj+1,:,:,:], theta[jj,:,:], samp_ratio=1)
        end
        #e_fwd[npl+1,:,:,:] = light_prop(e_fwd_m, d[npl], dl, lmbd)
        e_fwd[npl+2,:,:,:] = forwardPropagate(e_fwd_m, npl)

        # Our "loss" function (actually, want this to be 1, not zero)
        couple_eff = sum(abs.(e_fwd[npl+1,:,:,:].*conj.(e_out)))/nmod
        @printf "%d forward iteration, couple efficiency %f \n" ii couple_eff

        # Below here is specialized for the alternating minimization code

        # backward update
        e_bwd_m = e_out # initial modulated field
        for jj = 1:npl
            #e_bwd[-jj-2,:,:,:] = light_prop(e_bwd_m, -d[jj-1], dl, lmbd)
            e_bwd[end-jj,:,:,:] = backwardPropagate(e_bwd_m, ind[jj])
            e_sum = sum(e_fwd[end-jj,:,:,:].*conj.(e_bwd[end-jj,:,:,:]), dims=1)
            theta[end-jj+1,:,:] = -angle.(e_sum) # updates
            e_bwd_m = phase_mod(e_bwd[end-jj,:,:,:], -theta[end-jj+1,:,:], samp_ratio=1)
        end
        # e_bwd[0,:,:,:] = light_prop(e_bwd_m, -d[0], dl, lmbd)
        e_bwd[1,:,:,:] = backwardPropagate(e_bwd_m, 1)
        couple_eff = sum(abs.(e_in.*conj.(e_bwd[1,:,:,:])))/nmod
        @printf "%d backward iteration, couple efficiency %f \n" ii couple_eff
    end
    return theta, e_bwd_m, e_fwd_m
end
# %prun theta, e_bwd_m, e_fwd_m = mainLoop() # profile
etime = @timed mainLoop()
#theta, e_bwd_m, e_fwd_m = mainLoop()
# Out:
# 1 forward iteration, couple efficiency 0.651747
# 1 backward iteration, couple efficiency 0.542015
# 2 forward iteration, couple efficiency 0.724378
# 2 backward iteration, couple efficiency 0.599795
# 3 forward iteration, couple efficiency 0.736510
# 3 backward iteration, couple efficiency 0.627298
# 4 forward iteration, couple efficiency 0.745893
# 4 backward iteration, couple efficiency 0.645541
# 5 forward iteration, couple efficiency 0.755455
# 5 backward iteration, couple efficiency 0.661320
# 6 forward iteration, couple efficiency 0.763174
# 6 backward iteration, couple efficiency 0.672292
# 7 forward iteration, couple efficiency 0.767777
# 7 backward iteration, couple efficiency 0.680309
# 8 forward iteration, couple efficiency 0.772074
# 8 backward iteration, couple efficiency 0.686326
# 9 forward iteration, couple efficiency 0.775546
# 9 backward iteration, couple efficiency 0.691487
# 10 forward iteration, couple efficiency 0.778377
# 10 backward iteration, couple efficiency 0.695635
# 11 forward iteration, couple efficiency 0.781193
# 11 backward iteration, couple efficiency 0.699607
# 12 forward iteration, couple efficiency 0.784009
# 12 backward iteration, couple efficiency 0.702741
# 13 forward iteration, couple efficiency 0.786252
# 13 backward iteration, couple efficiency 0.705780
# 14 forward iteration, couple efficiency 0.788801
# 14 backward iteration, couple efficiency 0.708680
# 15 forward iteration, couple efficiency 0.790852
# 15 backward iteration, couple efficiency 0.711525
# 16 forward iteration, couple efficiency 0.792182
# 16 backward iteration, couple efficiency 0.714262
# 17 forward iteration, couple efficiency 0.793164
# 17 backward iteration, couple efficiency 0.716671
# 18 forward iteration, couple efficiency 0.794178
# 18 backward iteration, couple efficiency 0.718777
# 19 forward iteration, couple efficiency 0.794857
# 19 backward iteration, couple efficiency 0.720404
# 20 forward iteration, couple efficiency 0.795459
# 20 backward iteration, couple efficiency 0.722068
# 21 forward iteration, couple efficiency 0.795791
# 21 backward iteration, couple efficiency 0.723867
# 22 forward iteration, couple efficiency 0.796295
# 22 backward iteration, couple efficiency 0.724799
# 23 forward iteration, couple efficiency 0.796352
# 23 backward iteration, couple efficiency 0.725906
# 24 forward iteration, couple efficiency 0.797524
# 24 backward iteration, couple efficiency 0.726873
# 25 forward iteration, couple efficiency 0.798458
# 25 backward iteration, couple efficiency 0.728359
# 26 forward iteration, couple efficiency 0.800208
# 26 backward iteration, couple efficiency 0.730350
# 27 forward iteration, couple efficiency 0.800990
# 27 backward iteration, couple efficiency 0.732504
# 28 forward iteration, couple efficiency 0.802551
# 28 backward iteration, couple efficiency 0.735247
# 29 forward iteration, couple efficiency 0.803636
# 29 backward iteration, couple efficiency 0.736834
# 30 forward iteration, couple efficiency 0.805616
# 30 backward iteration, couple efficiency 0.740175
# 31 forward iteration, couple efficiency 0.808403
# 31 backward iteration, couple efficiency 0.742768
# 32 forward iteration, couple efficiency 0.810358
# 32 backward iteration, couple efficiency 0.745082
# 33 forward iteration, couple efficiency 0.812433
# 33 backward iteration, couple efficiency 0.747218
# 34 forward iteration, couple efficiency 0.814311
# 34 backward iteration, couple efficiency 0.749410
# 35 forward iteration, couple efficiency 0.815470
# 35 backward iteration, couple efficiency 0.751618
# 36 forward iteration, couple efficiency 0.816769
# 36 backward iteration, couple efficiency 0.753403
# 37 forward iteration, couple efficiency 0.817833
# 37 backward iteration, couple efficiency 0.754979
# 38 forward iteration, couple efficiency 0.818827
# 38 backward iteration, couple efficiency 0.756532
# 39 forward iteration, couple efficiency 0.819747
# 39 backward iteration, couple efficiency 0.758088
# 40 forward iteration, couple efficiency 0.820532
# 40 backward iteration, couple efficiency 0.759390
# 41 forward iteration, couple efficiency 0.821580
# 41 backward iteration, couple efficiency 0.760877
# 42 forward iteration, couple efficiency 0.822747
# 42 backward iteration, couple efficiency 0.762535
# 43 forward iteration, couple efficiency 0.823831
# 43 backward iteration, couple efficiency 0.764037
# 44 forward iteration, couple efficiency 0.824967
# 44 backward iteration, couple efficiency 0.765584
# 45 forward iteration, couple efficiency 0.825853
# 45 backward iteration, couple efficiency 0.767094
# 46 forward iteration, couple efficiency 0.826889
# 46 backward iteration, couple efficiency 0.768315
# 47 forward iteration, couple efficiency 0.827953
# 47 backward iteration, couple efficiency 0.769594
# 48 forward iteration, couple efficiency 0.828893
# 48 backward iteration, couple efficiency 0.770752
# 49 forward iteration, couple efficiency 0.829733
# 49 backward iteration, couple efficiency 0.772175
# 50 forward iteration, couple efficiency 0.830672
# 50 backward iteration, couple efficiency 0.773726
# 51 forward iteration, couple efficiency 0.831558
# 51 backward iteration, couple efficiency 0.775290
# 52 forward iteration, couple efficiency 0.832606
# 52 backward iteration, couple efficiency 0.776663
# 53 forward iteration, couple efficiency 0.833756
# 53 backward iteration, couple efficiency 0.777783
# 54 forward iteration, couple efficiency 0.834813
# 54 backward iteration, couple efficiency 0.778865
# 55 forward iteration, couple efficiency 0.835951
# 55 backward iteration, couple efficiency 0.780027
# 56 forward iteration, couple efficiency 0.836750
# 56 backward iteration, couple efficiency 0.780947
# 57 forward iteration, couple efficiency 0.837492
# 57 backward iteration, couple efficiency 0.781994
# 58 forward iteration, couple efficiency 0.838179
# 58 backward iteration, couple efficiency 0.782846
# 59 forward iteration, couple efficiency 0.839061
# 59 backward iteration, couple efficiency 0.783571
# 60 forward iteration, couple efficiency 0.839732
# 60 backward iteration, couple efficiency 0.784244
# 61 forward iteration, couple efficiency 0.840486
# 61 backward iteration, couple efficiency 0.784917
# 62 forward iteration, couple efficiency 0.841079
# 62 backward iteration, couple efficiency 0.785585
# 63 forward iteration, couple efficiency 0.841593
# 63 backward iteration, couple efficiency 0.786194
# 64 forward iteration, couple efficiency 0.841642
# 64 backward iteration, couple efficiency 0.786864
# 65 forward iteration, couple efficiency 0.842045
# 65 backward iteration, couple efficiency 0.787496
# 66 forward iteration, couple efficiency 0.842643
# 66 backward iteration, couple efficiency 0.788331
# 67 forward iteration, couple efficiency 0.842978
# 67 backward iteration, couple efficiency 0.788993
# 68 forward iteration, couple efficiency 0.843045
# 68 backward iteration, couple efficiency 0.789889
# 69 forward iteration, couple efficiency 0.843375
# 69 backward iteration, couple efficiency 0.790517
# 70 forward iteration, couple efficiency 0.844475
# 70 backward iteration, couple efficiency 0.791384
# 71 forward iteration, couple efficiency 0.845609
# 71 backward iteration, couple efficiency 0.793229
# 72 forward iteration, couple efficiency 0.846543
# 72 backward iteration, couple efficiency 0.794641
# 73 forward iteration, couple efficiency 0.847296
# 73 backward iteration, couple efficiency 0.795848
# 74 forward iteration, couple efficiency 0.847765
# 74 backward iteration, couple efficiency 0.796917
# 75 forward iteration, couple efficiency 0.848242
# 75 backward iteration, couple efficiency 0.797713
# 76 forward iteration, couple efficiency 0.848794
# 76 backward iteration, couple efficiency 0.798568
# 77 forward iteration, couple efficiency 0.849042
# 77 backward iteration, couple efficiency 0.799428
# 78 forward iteration, couple efficiency 0.849568
# 78 backward iteration, couple efficiency 0.800191
# 79 forward iteration, couple efficiency 0.849944
# 79 backward iteration, couple efficiency 0.800885
# 80 forward iteration, couple efficiency 0.850521
# 80 backward iteration, couple efficiency 0.801633
# 81 forward iteration, couple efficiency 0.851198
# 81 backward iteration, couple efficiency 0.802353
# 82 forward iteration, couple efficiency 0.851912
# 82 backward iteration, couple efficiency 0.803100
# 83 forward iteration, couple efficiency 0.852760
# 83 backward iteration, couple efficiency 0.803817
# 84 forward iteration, couple efficiency 0.853449
# 84 backward iteration, couple efficiency 0.804784
# 85 forward iteration, couple efficiency 0.854042
# 85 backward iteration, couple efficiency 0.805576
# 86 forward iteration, couple efficiency 0.854543
# 86 backward iteration, couple efficiency 0.806393
# 87 forward iteration, couple efficiency 0.855143
# 87 backward iteration, couple efficiency 0.807303
# 88 forward iteration, couple efficiency 0.855807
# 88 backward iteration, couple efficiency 0.808207
# 89 forward iteration, couple efficiency 0.856577
# 89 backward iteration, couple efficiency 0.809180
# 90 forward iteration, couple efficiency 0.857420
# 90 backward iteration, couple efficiency 0.809877
# 91 forward iteration, couple efficiency 0.858064
# 91 backward iteration, couple efficiency 0.810630
# 92 forward iteration, couple efficiency 0.858735
# 92 backward iteration, couple efficiency 0.811511
# 93 forward iteration, couple efficiency 0.859558
# 93 backward iteration, couple efficiency 0.812283
# 94 forward iteration, couple efficiency 0.860098
# 94 backward iteration, couple efficiency 0.812958
# 95 forward iteration, couple efficiency 0.860699
# 95 backward iteration, couple efficiency 0.813779
# 96 forward iteration, couple efficiency 0.861188
# 96 backward iteration, couple efficiency 0.814609
# 97 forward iteration, couple efficiency 0.861555
# 97 backward iteration, couple efficiency 0.815195
# 98 forward iteration, couple efficiency 0.861829
# 98 backward iteration, couple efficiency 0.815693
# 99 forward iteration, couple efficiency 0.862222
# 99 backward iteration, couple efficiency 0.816129
# 100 forward iteration, couple efficiency 0.862645
# 100 backward iteration, couple efficiency 0.816397
# syntax: incomplete: "for" at none:1 requires end

# %%
theta, e_bwd_m, e_fwd_m = etime[1]
etime.time
# Out:
# type Tuple has no field time
#
# Stacktrace:
#  [1] getproperty(::Tuple{Tuple{Array{Float64,3},Array{Complex{Float64},3},Array{Float64,3}},Float64,Int64,Float64,Base.GC_Diff}, ::Symbol) at .\Base.jl:33
#  [2] top-level scope at In[65]:2

# %%
# verify
e = zeros(ComplexF64,(npl+2,nmod,nx,ny)) 
e[1,:,:,:] = e_in
e_m = e_in # modulated field
for jj = 1:npl
    e[jj+1,:,:,:] = light_prop(e_m, d[jj], dl=dl, lmbd=lmbd)#backpropagates        
    e_m = phase_mod(e[jj+1,:,:,:], theta[jj,:,:], samp_ratio=1)
end

e_o = light_prop(e_m,d[end],dl=dl,lmbd=lmbd);

# %%
fig, ax = plt.subplots()
img=ax.imshow(theta[1,:,:],extent=(x[1],x[end],y[1],y[end]))
cbar=plt.colorbar(img)

fig, ax = plt.subplots()
img=ax.imshow(theta[2,:,:],extent=(x[1],x[end],y[1],y[end]))
cbar=plt.colorbar(img)
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x00000000017B4D08>

# %%
fig, ax = plt.subplots()
img = ax.imshow(np.abs(e_o[1,:,:]),extent=(x[1],x[end],y[1],y[end]))
cbar = plt.colorbar(img)
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x000000003C7F3988>

# %%
fig, ax = plt.subplots()
img = ax.imshow(np.abs(e_o[5,:,:]),extent=(x[1],x[end],y[1],y[end]))
cbar = plt.colorbar(img)
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x000000003E25DB48>
